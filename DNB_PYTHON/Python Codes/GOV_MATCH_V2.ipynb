# %%
import pandas as pd
from tqdm import tqdm
from rapidfuzz import fuzz, process
import numpy as np
import string
tqdm.pandas()

##This portion just surpresses warnings that do not affect the performance of the code.
import warnings
warnings.filterwarnings("ignore")

# %%
#These Dictionaries ensure that the read csv command gets the correct data types for columns
O_col={'PRIMARYINSUREDNAME': str, 'STREETADDRESS_OPT': str, 'CITY_OPT': str, 'ZIP_OPT':str,
       'Cleaned_Name':str, 'OC_Add':str, 'O_Add_#':float, 'O_Add_Name':str}

G_col={'Business Name':str, 'Address 1':str, 'Address 2':str, 'City':str, 'State':str, 'Zip':str,
       'Geocoded Location':str, 'Trade name':str, 'Adj_BN':str, 'Adj_Add':str, 'G_Add_#': float,
       'G_Add_Name':str}

# %%
# #Dataread for Government Data
Gpath=r"C:\Users\khat\OneDrive - PENNSYLVANIA COMPENSATION RATING BUREAU\Desktop\DNB_Data_Matching\Local Data\Generated\GOV_PREPD.csv"
GDF=pd.read_csv(Gpath, dtype=G_col)

#Shape check and Head Check for Government Data
print(GDF.shape)
GDF.head()
# Out:
# (2374999, 12)
#       Business Name         Address 1  Address 2        City State    Zip  \
# 0     Greenacy, Llc  600 N 2nd Street  4th Floor  harrisburg    PA  17101
# 1  Alphamed Rx Inc.  502 W 7th Street  Suite 100        erie    PA  16502
# 2         Legam Llc  502 W 7th Street  Suite 100        erie    PA  16502
# 3    Lycobirds, Llc      502 W 7th St    Ste 100        erie    PA  16502
# 4     Cotoletta Llc  600 N 2nd Street  4th Floor  harrisburg    PA  17101
#
#               Geocoded Location     Trade name       Adj_BN  \
# 0  (-76.888068038 40.263499986)  No Trade Name     greenacy
# 1   (-80.095924977 42.12455901)  No Trade Name  alphamed rx
# 2   (-80.095924977 42.12455901)  No Trade Name        legam
# 3   (-80.095924977 42.12455901)  No Trade Name    lycobirds
# 4  (-76.888068038 40.263499986)  No Trade Name    cotoletta
#
#               Adj_Add  G_Add_#       G_Add_Name
# 0  600 n 2nd st 4th #    600.0   n 2nd st 4th #
# 1  502 w 7th st # 100    502.0   w 7th st # 100
# 2  502 w 7th st # 100    502.0   w 7th st # 100
# 3  502 w 7th st # 100    502.0   w 7th st # 100
# 4  600 n 2nd st 4th #    600.0   n 2nd st 4th #

# %%
OP_path=r"C:\Users\khat\OneDrive - PENNSYLVANIA COMPENSATION RATING BUREAU\Desktop\DNB_Data_Matching\Local Data\Generated\OPTI_Unmatch_78.csv"
ODF=pd.read_csv(OP_path, dtype=O_col)
ODF['ZIP_OPT']= ODF['ZIP_OPT'].astype(str)
print(ODF.shape)
ODF.head()
# Out:
# (127266, 8)
#                        PRIMARYINSUREDNAME  \
# 0                     HYDRITE CHEMICAL CO
# 1                          SUNRISE VALLEY
# 2  DIOCESAN CENTRAL COUNCIL OF GREENSBURG
# 3       HOSPITAL HOUSEKEEPING SYSTEMS LLC
# 4                ANYWHERE REAL ESTATE INC
#
#                             STREETADDRESS_OPT     CITY_OPT ZIP_OPT  \
# 0                          208 WASHINGTON AVE    ellendale   19941
# 1  CONSTRUCTION LLC        239 SPRINGVILLE RD      kinzers   17535
# 2                          70 N MT VERNON AVE    uniontown   15401
# 3                              155 WILSON AVE   washington   15301
# 4                              3865 REED BLVD  murrysville   15668
#
#                              Cleaned_Name  \
# 0                     hydrite chemical co
# 1                          sunrise valley
# 2  diocesan central council of greensburg
# 3           hospital housekeeping systems
# 4                    anywhere real estate
#
#                                        OC_Add  O_Add_#  \
# 0                          208 washington ave    208.0
# 1  construction llc        239 springville rd      NaN
# 2                          70 n mt vernon ave     70.0
# 3                              155 wilson ave    155.0
# 4                              3865 reed blvd   3865.0
#
#                                    O_Add_Name
# 0                              washington ave
# 1  construction llc        239 springville rd
# 2                             n mt vernon ave
# 3                                  wilson ave
# 4                                   reed blvd

# %%
#Creating new columns for each dataset that just contains the first 4 digits zip code
#This allows for the code to only check nearby businesses
ODF['APPROX_ZIP_OPT'] = ODF['ZIP_OPT'].astype(str).str[:4].astype(int)
GDF['APPROX_ZIP_GOV'] = GDF['Zip'].astype(str).str[:4].astype(int)

# %%
#These are the submatching functions that actually apply the matching for individual rows
#================================================
#Secondary Address handler:
def suite_cleaner(text1, text2):
    ''' 
    Inputs: 
    text1: A single string of address data from optimus data
    text2: A single string of address data from Gov data

    Ouputs: A single Boolean

    Description: This function matches secondary address numbers/codes such as suite, floor, unit etc. and returns a boolean if the
    addresses have matching secondary address numbers. True indicates either a match or an assymetry of data, 
    meaning one or both of the addresses doesnt have a secondary address. This boolean is used in an upcoming function
    ''' 
    #Remove all spaces from both input strings
    text1 = text1.replace(" ", "")
    text2 = text2.replace(" ", "")

    #Find the generic pound sign symbolizing a the prescence of a secondary address
    index1 = text1.find('#')
    index2 = text2.find('#')
    
    #If either are missing the pound sign, return True
    if index1 == -1 or index2 == -1:
        return True 
    #Log the secondary address numbers
    else:
        start1 = index1 + 1
        start2 = index2 + 1    
        text1= text1[start1:]
        text2= text2[start2:]

        #Check for secondary Address equality
        if text1 == text2:
            return True
        else:
            return False


#==========================================
#Address Fuzzy Matcher:
def a_fm(num1,rem1,num2, rem2):
    '''
    Input:
    num1: The leading address number from an address string from optimus
    num2: The leading address number from an address string from Gov data
    rem1: The second part of an address string from optimus
    rem2: The second part of an address string from Gov

    Output:
    final_score: a match score from 0 - 1 that indicates the match score

    Description: This function using the simple rapidfuzz ratio (normalized distance) on the rem1 and rem2 part of the addresses, but
    also applies custom penalties based on address number and secondary address numbers. This ensures more accurate address matches.

    
    '''
    #Removes leading and trailing spaces
    
    rem1=str(rem1).strip()
    rem2=str(rem2).strip()   
    
    #Checks if leading numbers match
    num_match = num1 == num2 
    #Fuzzy match address info
    fuzz_score = fuzz.ratio(rem1, rem2) / 100
    
    #Check if secondary address number matches
    sc=suite_cleaner(rem1, rem2)
    
    #Apply penalties to fuzzy match score
    #If suite numbers mismatch, apply a -.2 penalty
    if sc is False:
        fuzz_score-=.2

    #If leading numbers do not match: apply a -.35 penalty
    if not num_match:
        fuzz_score -= 0.35  
    
    #Safety Catch to stop negative scores from occuring, thus setting the floor at 0
    final_score = max(fuzz_score, 0) 
    
    return final_score
#===========================================
#Name fuzzy match
def n_fm(b1,b2):
    ''' 
    Inputs: 
    b1: a single string containg the business name from optimus
    b2: a single string containg the business name from the government data

    Outputs:
    nscore: A fuzzymatch score from 0-1

    Description: This function averages two distinct fuzzy matching scoring algorithms, Weighted ratio and standard ratio,

    '''
    Rscore=fuzz.ratio(b1,b2)/ 100
    Wscore=fuzz.WRatio(b1,b2)/100
    nscore=(Wscore + Rscore)/2
   
    return(nscore)

#========================================================
#Full matching function:

def manual_extract_one(nquery, a_num, a_st, cquery, nchoices, addnums,addsts, cchoices):
    '''    
    Inputs: 
    nquery: a string containing a business name from Optimus
    a_num: a string containing a business address number from Optimus
    a_st: a string containing a business address remainder from Optimus
    cquery: a string containing a business' city from Optimus
    nchoices: a column of a dataframe containg strings of business names from Gov data
    addnums: a column of a dataframe containg strings of address numbers from Gov data
    addsts: a column of a dataframe containg strings of address remainders from Gov data
    cchoices: a column of a dataframe containg strings of business cities from Gov data

    Outputs:
    best_index: The index of the row in the Gov dataframe that is the best match for the current row in Optimus
    best_score: the best total Match Score for the row
    BestN: The name score for the best index row for business name
    BestA: The address score for the best index row for business address
    BestC: The city score for the best index row for business city

    Description: This function applies the name and address matching functions from above to whole rows of Governmen data. It selects a single row
    of Optimus data and then iterates row by row through the Gov data, until it finds the best match
    '''
    #Initializing best score and best index variables
    best_score = 0
    best_index = -1
    bestN=''
    bestA=''
    bestC=0
    Nscore=0
    Ascore=0
    Cscore=0
    #Main loop that goes row by row
    for index, (nchoice, a_num_choice, a_st_choice, cchoice) in enumerate(zip(nchoices, addnums, addsts, cchoices)):
        # Perform fuzzy matching for Name and Addresss
        Nscore = n_fm(nquery, nchoice)
        Ascore = a_fm(a_num, a_st, a_num_choice, a_st_choice)
        #City Score
        Cscore=n_fm(cquery, cchoice)
        #If city score is greater than .9, the penalty term is set to 0
        if Cscore >.9:
            Cmod=0
        #Apply a penalty term for low city score of -.1
        else:
            Cmod= .1
        # Average the scores and subtract the City penalty
        avg_score = ((0.5*Nscore) + (0.5*Ascore))-Cmod

        # Update best match if the new average score is better
        if avg_score > best_score:
            best_score = avg_score
            best_index = index
            bestN=Nscore
            bestA=Ascore
            bestC=Cscore
          
        # If a good match occurs, stop the loop to speed up processing time
        if best_score >= .92:
            break
  
    return best_index, best_score, bestN, bestA, bestC

# %%
#Function that applies manual_extract_one to every row of optimus
def find_match(row, choices):
    ''' 
    input:
    row: A single row of the Optimus dataframe
    choices: The government dataframe

    Output: A single list that contains all the outputs of the manual_extract_one. It will contain False and 0's in the event of an error

    Description: This function narrows down the potential choices of the Gov dataframe to only rows with the same first four digits of zipcode. It also handles errors and the event
    of an empty choices df
    '''
    try:
        #Filter down the potential matches by approx zip code
        choices_filtered = choices[(choices['APPROX_ZIP_GOV'] == row['APPROX_ZIP_OPT'])]

        if choices_filtered.empty:
            return [False, 0, 0, 0,0]
        
        # Call the manual_extract_one function for fuzzy matching scores
        index, total_score, namescore, addscore, cscore = manual_extract_one(row['Cleaned_Name'], 
                                                                             row['O_Add_#'], row['O_Add_Name'], 
                                                                             row['CITY_OPT'], choices_filtered['Adj_BN'], 
                                                                             choices_filtered['G_Add_#'], choices_filtered['G_Add_Name'], choices_filtered['City'])
        #Handle the case where no match is found
        if index is None:
            return [None, 0, 0, 0,0]
        # Return results when match is found
        else:
            original_index = choices_filtered.index[index]
         
            return [original_index, total_score, namescore, addscore, cscore]
    #Handle all errors and empty rows
    except Exception as e:
        # Return default values 
 
        print(f"Error in find_match: {e}")
        return [False, 0, 0, 0,0]

# %%
#================================================================================================
#Main Function
def main(DF, Gov):
    ''' 
    input: 
    DF: This is the optimus df
    Gov: This is the Gov df

    Outputs:
    RDF: A formatted df with the matches appended

    Description: This function runs find match and handles loading bars, and reformats the results intoa df
    '''
    results = []  # List to collect result dictionaries
    errors=0
    # Iterate through rows of Optimus data
    for _, row in tqdm(DF.iterrows(), total=DF.shape[0], desc='Performing Fuzzy Matching'): 
        # Get the best match index and score from find_match
        MATCH = find_match(row, Gov)
    
        # Skip if no match found
        if not MATCH:
            continue

        # Unpack the match results into individual variables
        match_index, score, namescore, addscore, cscore = MATCH[0], MATCH[1], MATCH[2], MATCH[3], MATCH[4]
        
        # Check if a valid match was found
        if match_index is False:
            errors+=1
            # Handle case when no valid match is found by creating a blank row
            blank = pd.DataFrame(np.nan, columns=Gov.columns, index=[0])
            mrow = blank.iloc[0]
        else:
            # Get the matched row from Gov data using the index
            mrow = Gov.iloc[match_index]
        
        # Create a result dictionary with the selected data from both Optimus and Gov
        result = {
            "OPTI_Name": row['PRIMARYINSUREDNAME'],
            "Name Score": namescore,
            "Address Score": addscore,
            "City Score": cscore, 
            "Match Score": score,
            "Opti_Address": row['STREETADDRESS_OPT'], 
            "Opti_City": row['CITY_OPT'],  
            "Opti_Zip": row['ZIP_OPT']
        }

        # Add matched row data from Gov to result
        result.update(mrow.to_dict())  
        results.append(result)
    #Convert to a pandas dataframe
    RDF = pd.DataFrame(results)
    #Select custom columns
    RDF=RDF[['OPTI_Name','Business Name', 'Name Score',
              'Opti_Address', 'Address 1', 'Address 2', 'Address Score', 
              'Opti_City','City', "City Score",
              'Opti_Zip', 'Zip', 'Match Score',
              'State', 'Geocoded Location', 'Trade name', 'Adj_BN', 'Adj_Add', 'G_Add_#', 'G_Add_Name' ]]
    RDF=pd.DataFrame(RDF)
    print(f"{errors} occured")
    return RDF

# %%
df=ODF.sample(1800, random_state=961)

#11 is a good seed
R=main(df,GDF)


#Resturcturing R


RQ = R[(R['Match Score']>0.73) ] 
RQ.sort_values(by='Match Score', ascending=True, inplace=True)
RQ['Zip']=RQ['Zip'].astype(int)
print(f"{(len(RQ)/len(R))*100}% Match Rate")
RQ.head(45)
# Out:
# Performing Fuzzy Matching:   0%|          | 0/1800 [00:00<?, ?it/s]
# Performing Fuzzy Matching: 100%|██████████| 1800/1800 [04:02<00:00,  7.41it/s]
# 0 occured
# 11.722222222222223% Match Rate
#                                               OPTI_Name  \
# 1050                          CSS BUILDING SERVICES INC
# 73                      ENVIRONMENTAL SERVICES CONCEPTS
# 1476     THE SUSAN G KOMEN BREAST CANCER FOUNDATION INC
# 1730                                     LIVEACTION INC
# 658                       HEALTH ADVOCATE SOLUTIONS INC
# 971                                 SP PLUS CORPORATION
# 503                                      LAFLIN BOROUGH
# 15                                          GENESCO INC
# 800                               ACRISURE HOLDINGS INC
# 536           WESTFALL TOWNSHIP VOLUNTEER FIRE DEPT INC
# 820                                         GREINER INC
# 1646                         MISSION HILL ASSOCIATES LP
# 1382                                NEWTOWN BOROUGH VFC
# 1327                                     DSSS FOOD CORP
# 869                        CITY BEVERAGE OF ALTOONA INC
# 244                        WALGREENS BOOTS ALLIANCE INC
# 1578                            BALASCIO EXCAVATING LLC
# 818                      HOLISTIX TREATMENT CENTERS LLC
# 498                              LOUIS A DANGELO DMD PC
# 1584                                 EAST COAST HAIR CO
# 715                                 SAW RESTORATION LLC
# 272                     EL SAGUARO INC DBA CASA HERRERA
# 1555         LOVE PRAY PEACE PROJECT VETERANS RESIDENCE
# 1252                        MONTROSE BUICK GMC CADILLAC
# 184   TEACHERS INSURANCE AND ANNUITY ASSOCIATIONCOLL...
# 254         BUSINESS RECORD MANAGEMENT SERVICES INC DBA
# 708       UNIVERSITY OF MARYLAND FACULTY PHYSICIANS INC
# 359                  FRANKLIN MINT FEDERAL CREDIT UNION
# 560                               COMPASS GROUP USA INC
# 89                                     ADAPTHEALTH CORP
# 415                                      LAZER SPOT INC
# 1245                         CHRISTOPHER A SNYDER DO PC
# 1672                            ENC HOLDING CORPORATION
# 1595                             PARKING AGGREGATOR LLC
# 369                                 GULIA OMENE DMD LLC
# 740                                         SYBRINC INC
# 1656                                 RGI MANAGEMENT LLC
# 191                       THE MICHAELS ORGANIZATION LLC
# 711                         ADVANCED FOOT  ANKLE CENTER
# 0     MUNICIPALITY OF NORRISTOWN AND NORRISTOWN FIRE...
# 327                                    ATT SERVICES INC
# 374                      JUSTWORKS EMPLOYMENT GROUP LLC
# 26                              LAZ KARP ASSOCIATES LLC
# 1528                                        SR95TK5 LLC
# 270                                 ZAMIAS SERVICES INC
#
#                                           Business Name  Name Score  \
# 1050                                 Csi Services, Inc.    0.791136
# 73      525 Virginia Drive Associates Acquisition Corp.    0.441558
# 1476                      Moses Taylor Foundation, Inc.    0.689038
# 1730                                     Novacomm, Inc.    0.444444
# 658                       American Telecast Corporation    0.444444
# 971                                   K K K Corporation    0.796528
# 503   Laflin Borough Volunteer Fire Department Ladie...    0.647183
# 15                                   4600 Jonestown Llc    0.447619
# 800                                  3.31 Holdings, Llc    0.690345
# 536                           Mill Rift Fire Department    0.483871
# 820                            Rotelle Investments, Llc    0.449451
# 1646                                 Mrn Associates, Lp    0.799593
# 1382                Newtown Firemens Relief Association    0.649722
# 1327                  Musselwhite's Milford Diner, Inc.    0.450000
# 869                      City Beverage of Altoona, Inc.    1.000000
# 244                                    HAPPY HARRYS INC    0.451399
# 1578          Uwchlan Hills Home and School Association    0.453125
# 818            Home Is Where the Heart Is Home Care Llc    0.454510
# 498                       Michael F. Lentz D.d.s., P.c.    0.454545
# 1584     Barnberry Associates, Inc. a Close Corporation    0.456897
# 715                            Nri Energy Solutions Llc    0.457143
# 272                         Yaser Family Restaurant Inc    0.457143
# 1555                           Earl Ray Enterprises Llc    0.457177
# 1252                         Montrose P&c Insurance Llc    0.583333
# 184   Elle & Me Developmental and Behavioral Service...    0.602500
# 254                            Bluewater Services, Inc.    0.673114
# 708                        White Rose Foot and Ankle Pc    0.463768
# 359                              CARITAS MANAGEMENT LLC    0.465753
# 560                                 Simpson House, Inc.    0.466667
# 89                                 For Your Health, Llc    0.469355
# 415                           Brasler Industrial #4 Llc    0.470000
# 1245                       Tri County Dermatology, P.c.    0.470588
# 1672                            Ctx Holding Corporation    0.913043
# 1595            Pennsylvania Endocrine Laboratory, P.c.    0.472222
# 369                          The Omene Dental Group Llc    0.472973
# 740                                       Sybrnic, Inc.    0.857143
# 1656                                Pran Management Inc    0.827586
# 191    Wister Townhouse Apartments Resident Association    0.479704
# 711                           FOOT AND ANKLE ASSOCIATES    0.752801
# 0     The Police Pension Fund of the Borough of Norr...    0.482438
# 327                             Shail Enterprises, Inc.    0.482759
# 374                             S&w Metal Products, Llc    0.484029
# 26          Franklin Town Health Care Center Associates    0.685565
# 1528                                       SR95TK5, LLC    0.768182
# 270                     C.c. Zamias Limited Partnership    0.677500
#
#                         Opti_Address                          Address 1  \
# 1050                  3737 MARKET ST                 1901 Market Street
# 73                    443 S GULPH RD                     443 S Gulph Rd
# 1476    125 N WASHINGTON AVE STE 260  125 N. Washington Ave., Suite 205
# 1730              125 S NORWINDEN DR                125 S. Norwinden Dr
# 658                835 SPRINGDALE DR                  835 Springdale Dr
# 971                  733 CHESTNUT ST               1626 Chestnut Street
# 503                     47 LAFLIN RD                       47 Laflin Rd
# 15                 4600 JONESTOWN RD                  4600 Jonestown Rd
# 800                  444 LIBERTY AVE      444 Liberty Avenue Suite 2100
# 536               139 BLUESTONE BLVD                139 Blue Stone Blvd
# 820                    1101 RIDGE RD                    1101 Ridge Road
# 1646              85018539 ALICIA ST                     8928 Alicia St
# 1382                   14 LIBERTY RD                  14 Liberty Street
# 1327                    301 BROAD ST                       301 Broad St
# 869                    526 E 6TH AVE                 525 East Sixth Ave
# 244                    396 E MAIN ST                      396 E MAIN ST
# 1578                      50 PECK RD                         50 Peck Rd
# 818               3831 ALBEMARLE AVE                 3831 Albemarle Ave
# 498                    2004 S 5TH ST              2004 South 5th Street
# 1584                  226 W BROAD ST                     226 W Broad St
# 715                1114 VIRGINIA WAY                 1114 Virginia Way,
# 272               2755 E LINCOLN HWY                 2755 E Lincoln Hwy
# 1555             6948 TORRESDALE AVE                6948 Torresdale Ave
# 1252             1455 N HERMITAGE RD         1455 N Hermitage Rd Unit a
# 184   201 KING OF PRUSSIA RD STE 650             201 King of Prussia Rd
# 254        951 ROHERSTOWN RD STE 201               951 Rohrerstown Road
# 708                  1880 KENNETH RD                    1880 Kenneth Rd
# 359                  2501 SEAPORT DR                    2501 SEAPORT DR
# 560                 2101 BELMONT AVE                   2101 Belmont Ave
# 89                   1295 GRAND BLVD               1295 Grand Boulevard
# 415                    600 MEMORY LN                    600 Memory Lane
# 1245                  20 N LAUREL ST                 20 N Laurel Street
# 1672               2150 CABOT BLVD W                      16 Cabot Blvd
# 1595                    330 S 9TH ST                       330 S 9th St
# 369              883 VALLEY FORGE RD              883 Valley Forge Road
# 740             800 SUMMIT RIDGE PLZ                 Summit Ridge Plaza
# 1656                  1619 GRANT AVE                     2013 Grant Ave
# 191                 292 E ASHMEAD ST                   292 E Ashmead St
# 711                    1415 FOULK RD              1415 FOULK RD STE 101
# 0                      235 E AIRY ST                      235 E Airy St
# 327                   1501 WALNUT ST                     1501 Walnut St
# 374               441 COUNTY LINE RD               441 County Line Road
# 26                    1500 LOCUST ST                     1500 Locust St
# 1528                333 N DUPONT HWY                  333 N DUPONT BLVD
# 270                300 MARKET ST OFC                      300 Market St
#
#      Address 2  Address Score        Opti_City             City  City Score  \
# 1050       NaN       0.650000     philadelphia     philadelphia    1.000000
# 73         NaN       1.000000  king of prussia  king of prussia    1.000000
# 1476       NaN       0.754545         scranton         scranton    1.000000
# 1730       NaN       1.000000      springfield      springfield    1.000000
# 658        NaN       1.000000            exton            exton    1.000000
# 971        NaN       0.650000     philadelphia     philadelphia    1.000000
# 503        NaN       1.000000     wilkes barre           laflin    0.223611
# 15         NaN       1.000000       harrisburg       harrisburg    1.000000
# 800        NaN       0.758621       pittsburgh       pittsburgh    1.000000
# 536        NaN       0.965517         millrift         millrift    1.000000
# 820        NaN       1.000000        pottstown        pottstown    1.000000
# 1646       NaN       0.650000     philadelphia     philadelphia    1.000000
# 1382       NaN       0.800000          newtown          newtown    1.000000
# 1327       NaN       1.000000          milford          milford    1.000000
# 869        NaN       0.450000          altoona          altoona    1.000000
# 244        NaN       1.000000       middletown       middletown    1.000000
# 1578       NaN       1.000000      downingtown      downingtown    1.000000
# 818        NaN       1.000000      drexel hill      drexel hill    1.000000
# 498        NaN       1.000000        allentown        allentown    1.000000
# 1584       NaN       1.000000        bethlehem        bethlehem    1.000000
# 715        NaN       1.000000       quakertown       quakertown    1.000000
# 272        NaN       1.000000      coatesville      coatesville    1.000000
# 1555       NaN       1.000000     philadelphia     philadelphia    1.000000
# 1252       NaN       0.875000        hermitage        hermitage    1.000000
# 184        NaN       0.857143           radnor           radnor    1.000000
# 254        NaN       0.787879        lancaster        lancaster    1.000000
# 708        NaN       1.000000             york             york    1.000000
# 359        NaN       1.000000          chester          chester    1.000000
# 560        NaN       1.000000     philadelphia     philadelphia    1.000000
# 89         NaN       1.000000         monessen         monessen    1.000000
# 415        NaN       1.000000             york             york    1.000000
# 1245       NaN       1.000000         hazleton         hazleton    1.000000
# 1672       NaN       0.559091        langhorne        langhorne    1.000000
# 1595       NaN       1.000000     philadelphia     philadelphia    1.000000
# 369        NaN       1.000000     phoenixville     phoenixville    1.000000
# 740        NaN       0.617742   mount pleasant   mount pleasant    1.000000
# 1656       NaN       0.650000     philadelphia     philadelphia    1.000000
# 191        NaN       1.000000     philadelphia     philadelphia    1.000000
# 711        NaN       0.727273       wilmington       wilmington    1.000000
# 0          NaN       1.000000       norristown       norristown    1.000000
# 327        NaN       1.000000     philadelphia     philadelphia    1.000000
# 374        NaN       1.000000    gilbertsville    gilbertsville    1.000000
# 26         NaN       1.000000     philadelphia            phila    0.744118
# 1528       NaN       0.720000           smyrna           smyrna    1.000000
# 270        NaN       0.818182        johnstown        johnstown    1.000000
#
#      Opti_Zip    Zip  Match Score State              Geocoded Location  \
# 1050    19104  19103     0.720568    PA   (-75.171933041 39.953814982)
# 73      19406  19406     0.720779    PA    (-75.36820201 40.077629983)
# 1476    18503  18503     0.721792    PA   (-75.664387036 41.407765011)
# 1730    19064  19064     0.722222    PA   (-75.320661029 39.928663992)
# 658     19341  19341     0.722222    PA   (-75.601053878 40.029387102)
# 971     19107  19104     0.723264    PA   (-75.168348018 39.951133989)
# 503     18702  18702     0.723592    PA   (-75.796448999 41.291299403)
# 15      17109  17109     0.723810    PA   (-76.816510976 40.302286991)
# 800     15222  15222     0.724483    PA      (-80.004709 40.440891986)
# 536     18340  18340     0.724694    PA   (-74.745101973 41.411786983)
# 820     19465  19465     0.724725    PA   (-75.666419731 40.175297302)
# 1646    19111  19115     0.724797    PA    (-75.057265002 40.09451298)
# 1382    18940  18940     0.724861    PA      (-74.935586003 40.229721)
# 1327    18337  18337     0.725000    PA   (-74.802092041 41.322963997)
# 869     16602  16602     0.725000    PA   (-78.382154013 40.526912986)
# 244     19709  19709     0.725699    DE  (39.450269006, -75.704709019)
# 1578    19335  19335     0.726562    PA    (-75.680668045 40.03290134)
# 818     19026  19026     0.727255    PA   (-75.294596998 39.940185002)
# 498     18103  18103     0.727273    PA   (-75.455788959 40.576813012)
# 1584    18018  18018     0.728448    PA   (-75.386504985 40.622630003)
# 715     18951  18951     0.728571    PA   (-75.327754968 40.462045018)
# 272     19320  19320     0.728571    PA   (-75.770115638 39.992044996)
# 1555    19135  19135     0.728589    PA   (-75.041830984 40.027026003)
# 1252    16148  16148     0.729167    PA           (-80.45142 41.25226)
# 184     19087  19087     0.729821    PA   (-75.356842017 40.043833982)
# 254     17601  17601     0.730496    PA   (-76.358333014 40.059341006)
# 708     17408  17401     0.731884    PA   (-76.780005021 39.981761002)
# 359     19013  19013     0.732877    PA           (39.8292, -75.38403)
# 560     19131  19131     0.733333    PA   (-75.216841804 39.990329195)
# 89      15062  15062     0.734677    PA   (-79.889854966 40.149836014)
# 415     17402  17402     0.735000    PA   (-76.686380001 39.981075991)
# 1245    18201  18201     0.735294    PA   (-75.975454969 40.955204014)
# 1672    19047  19047     0.736067    PA   (-74.856941958 40.191167011)
# 1595    19107  19107     0.736111    PA   (-75.156642166 39.944877276)
# 369     19460  19460     0.736486    PA   (-75.501095073 40.120470016)
# 740     15666  15666     0.737442    PA   (-79.547831105 40.127439079)
# 1656    19115  19115     0.738793    PA   (-75.032823959 40.083437008)
# 191     19144  19144     0.739852    PA   (-75.163404796 40.034544108)
# 711     19803  19803     0.740037    DE     (39.799849018, -75.523057)
# 0       19401  19401     0.741219    PA   (-75.339044973 40.114943995)
# 327     19102  19102     0.741379    PA   (-75.166027991 39.949815012)
# 374     19525  19525     0.742014    PA   (-75.618608014 40.339425989)
# 26      19102  19102     0.742782    PA    (-75.16668597 39.948248016)
# 1528    19977  19977     0.744091    DE   (39.306508009, -75.60732899)
# 270     15901  15901     0.747841    PA   (-78.921407023 40.324510015)
#
#                           Trade name  \
# 1050                   No Trade Name
# 73                     No Trade Name
# 1476                   No Trade Name
# 1730                   No Trade Name
# 658                    No Trade Name
# 971                    No Trade Name
# 503                    No Trade Name
# 15                     No Trade Name
# 800                    No Trade Name
# 536                    No Trade Name
# 820                    No Trade Name
# 1646                   No Trade Name
# 1382                   No Trade Name
# 1327                   No Trade Name
# 869                    No Trade Name
# 244                 WALGREENS #11067
# 1578                   No Trade Name
# 818                    No Trade Name
# 498                    No Trade Name
# 1584                   No Trade Name
# 715                    No Trade Name
# 272                    No Trade Name
# 1555                   No Trade Name
# 1252                   No Trade Name
# 184                    No Trade Name
# 254                    No Trade Name
# 708                    No Trade Name
# 359             CARITAS CONSTRUCTION
# 560                    No Trade Name
# 89                     No Trade Name
# 415                    No Trade Name
# 1245                   No Trade Name
# 1672                   No Trade Name
# 1595                   No Trade Name
# 369                    No Trade Name
# 740                    No Trade Name
# 1656                   No Trade Name
# 191                    No Trade Name
# 711   ADVANCED FOOT AND ANKLE CENTER
# 0                      No Trade Name
# 327                    No Trade Name
# 374                    No Trade Name
# 26                     No Trade Name
# 1528                    SR95TK5, LLC
# 270                    No Trade Name
#
#                                                  Adj_BN  \
# 1050                                       csi services
# 73       525 virginia drive associates acquisition corp
# 1476                            moses taylor foundation
# 1730                                           novacomm
# 658                       american telecast corporation
# 971                                   k k k corporation
# 503   laflin borough volunteer fire department ladie...
# 15                                       4600 jonestown
# 800                                        331 holdings
# 536                           mill rift fire department
# 820                                 rotelle investments
# 1646                                  mrn associates lp
# 1382                newtown firemens relief association
# 1327                         musselwhites milford diner
# 869                            city beverage of altoona
# 244                        happy harrys walgreens 11067
# 1578          uwchlan hills home and school association
# 818                home is where the heart is home care
# 498                              michael f lentz dds pc
# 1584           barnberry associates a close corporation
# 715                                nri energy solutions
# 272                             yaser family restaurant
# 1555                               earl ray enterprises
# 1252                              montrose pc insurance
# 184      elle  me developmental and behavioral services
# 254                                  bluewater services
# 708                        white rose foot and ankle pc
# 359             caritas management caritas construction
# 560                                       simpson house
# 89                                      for your health
# 415                                brasler industrial 4
# 1245                          tri county dermatology pc
# 1672                            ctx holding corporation
# 1595               pennsylvania endocrine laboratory pc
# 369                              the omene dental group
# 740                                             sybrnic
# 1656                                    pran management
# 191    wister townhouse apartments resident association
# 711   foot and ankle associates advanced foot and an...
# 0     the police pension fund of the borough of norr...
# 327                                   shail enterprises
# 374                                   sw metal products
# 26          franklin town health care center associates
# 1528                                    sr95tk5 sr95tk5
# 270                       cc zamias limited partnership
#
#                          Adj_Add  G_Add_#               G_Add_Name
# 1050              1901 market st   1901.0                market st
# 73                443 s gulph rd    443.0               s gulph rd
# 1476  125 n washington ave # 205    125.0   n washington ave # 205
# 1730          125 s norwinden dr    125.0           s norwinden dr
# 658            835 springdale dr    835.0            springdale dr
# 971             1626 chestnut st   1626.0              chestnut st
# 503                 47 laflin rd     47.0                laflin rd
# 15             4600 jonestown rd   4600.0             jonestown rd
# 800       444 liberty ave # 2100    444.0       liberty ave # 2100
# 536          139 blue stone blvd    139.0          blue stone blvd
# 820                1101 ridge rd   1101.0                 ridge rd
# 1646              8928 alicia st   8928.0                alicia st
# 1382               14 liberty st     14.0               liberty st
# 1327                301 broad st    301.0                 broad st
# 869              525 e sixth ave    525.0              e sixth ave
# 244                396 e main st    396.0                e main st
# 1578                  50 peck rd     50.0                  peck rd
# 818           3831 albemarle ave   3831.0            albemarle ave
# 498                2004 s 5th st   2004.0                 s 5th st
# 1584              226 w broad st    226.0               w broad st
# 715            1114 virginia way   1114.0             virginia way
# 272           2755 e lincoln hwy   2755.0            e lincoln hwy
# 1555         6948 torresdale ave   6948.0           torresdale ave
# 1252     1455 n hermitage rd # a   1455.0       n hermitage rd # a
# 184       201 king of prussia rd    201.0       king of prussia rd
# 254           951 rohrerstown rd    951.0           rohrerstown rd
# 708              1880 kenneth rd   1880.0               kenneth rd
# 359              2501 seaport dr   2501.0               seaport dr
# 560             2101 belmont ave   2101.0              belmont ave
# 89               1295 grand blvd   1295.0               grand blvd
# 415                600 memory ln    600.0                memory ln
# 1245              20 n laurel st     20.0              n laurel st
# 1672               16 cabot blvd     16.0               cabot blvd
# 1595                330 s 9th st    330.0                 s 9th st
# 369          883 valley forge rd    883.0          valley forge rd
# 740              summit ridgeplz      NaN          summit ridgeplz
# 1656              2013 grant ave   2013.0                grant ave
# 191             292 e ashmead st    292.0             e ashmead st
# 711          1415 foulk rd # 101   1415.0           foulk rd # 101
# 0                  235 e airy st    235.0                e airy st
# 327               1501 walnut st   1501.0                walnut st
# 374           441 county line rd    441.0           county line rd
# 26                1500 locust st   1500.0                locust st
# 1528           333 n dupont blvd    333.0            n dupont blvd
# 270                300 market st    300.0                market st

# %%
Anum=100
Aname='commerce dr'
Bnum=963
Bname='winterset rd'
a_fm(Anum, Aname, Bnum, Bname)
# Out:
# 0.08478260869565218

# %%
def dc_search(df, search_value, column_name):
    # Filter the DataFrame to only include rows where the specified column contains the search value
    filtered_df = df[df[column_name] == search_value]
    return(filtered_df.head())
# dc_search(GDF,'Polymath Park Resort Inc.','Business Name' )
